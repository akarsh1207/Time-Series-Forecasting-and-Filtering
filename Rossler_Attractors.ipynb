# %% [markdown]
# <a href="https://colab.research.google.com/github/akarsh1207/Time-Series-Forecasting-and-Filtering/blob/main/Rossler_Attractors.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Construction of a Lorenz Attractor
# ___

# %% [markdown]
# ## Importing the Libraries

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Defining Lorenz Function

# %%
def lorenz(X, Y, Z, a=0.2,b=0.2, c=5.7):
  x_dot = -Y-Z
  y_dot = X + a*Y
  z_dot = b + Z*(X-c)
  return x_dot, y_dot, z_dot

# %% [markdown]
# ## Time Loop

# %%
dt = 0.01
num_steps = 10000
x = np.empty(num_steps+1)
y = np.empty(num_steps+1)
z = np.empty(num_steps+1)
x[0], y[0], z[0] = (0.1,0.1,0.1)

for i in range(num_steps):
  x_dot,y_dot,z_dot=lorenz(x[i],y[i],z[i])
  x[i+1] = x[i] + (x_dot)*(dt)
  y[i+1] = y[i] + (y_dot)*(dt)
  z[i+1] = z[i] + (z_dot)*(dt)

# %% [markdown]
# ##Visualisation

# %%
Visualisation = plt.figure().add_subplot(projection='3d')

Visualisation.plot(x,y,z, lw=0.5)
Visualisation.set_xlabel("X Axis")
Visualisation.set_ylabel("Y Axis")
Visualisation.set_zlabel("Z Axis")
Visualisation.set_title("Rossler Attractor")

plt.show()

# %%
fig, (ax1,ax2,ax3) = plt.subplots(1,3, figsize = (15, 5))
ax1.plot(x, y)
ax1.set_title("X & Y")
ax2.plot(x, z)
ax2.set_title("X & Z")
ax3.plot(y, z)
ax3.set_title("Y & Z")
plt.show()

# %% [markdown]
# #Formulation of the Time Series
# ___

# %% [markdown]
# ##Multivariate Series Formation

# %%
x1 = x.reshape((len(x), 1))
y1 = y.reshape((len(y), 1))
z1 = z.reshape((len(z), 1))
T = np.hstack((x1,y1,z1))
print(T)
# Out:
# [[0.1        0.1        0.1       ]
#  [0.098      0.1012     0.0964    ]
#  [0.096024   0.1023824  0.09299967]
#  ...
#  [3.17206607 1.95375308 0.08893293]
#  [3.15163921 1.98938125 0.08868476]
#  [3.13085855 2.0248764  0.08842475]]
